// %% [markdown]
// This is a small test about how to link C++ code on a notebook

// %%
#include <iostream>
#include <stdio.h>
int main(){
    printf("I hate this!");
    std::cout << "I hate python/jupyter envs" << std::endl;
    return 0;
}
// Out:
// I hate python/jupyter envs
//
// I hate this!

// %%
int a = -10;
std::cout << "Valor: " << a << std::endl;
// Out:
// Valor:0
